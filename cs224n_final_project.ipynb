# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/cs224n/CS224N-Spring2024-DFP')

# %%
# !python classifier.py --fine-tune-mode full-model --lr 1e-5 --use_gpu
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# Downloading: 100% 232k/232k [00:00<00:00, 6.57MB/s]
# Downloading: 100% 570/570 [00:00<00:00, 2.88MB/s]
# Downloading: 100% 440M/440M [00:05<00:00, 84.6MB/s]
# train-0: 100% 1068/1068 [02:12<00:00,  8.09it/s]
# eval: 100% 1068/1068 [00:26<00:00, 40.59it/s]
# eval: 100% 138/138 [00:03<00:00, 40.22it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.270, train acc :: 0.588, dev acc :: 0.500
# train-1: 100% 1068/1068 [02:13<00:00,  8.03it/s]
# eval: 100% 1068/1068 [00:26<00:00, 40.45it/s]
# eval: 100% 138/138 [00:03<00:00, 42.83it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 0.963, train acc :: 0.728, dev acc :: 0.511
# train-2: 100% 1068/1068 [02:13<00:00,  8.02it/s]
# eval: 100% 1068/1068 [00:26<00:00, 40.42it/s]
# eval: 100% 138/138 [00:03<00:00, 42.94it/s]
# ...

# %%
# !python classifier.py --fine-tune-mode last-linear-layer --lr 1e-3 --use_gpu
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# train-0: 100% 1068/1068 [00:27<00:00, 39.22it/s]
# eval: 100% 1068/1068 [00:25<00:00, 41.14it/s]
# eval: 100% 138/138 [00:03<00:00, 40.37it/s]
# save the model to sst-classifier.pt
# Epoch 0: train loss :: 1.586, train acc :: 0.387, dev acc :: 0.369
# train-1: 100% 1068/1068 [00:27<00:00, 39.52it/s]
# eval: 100% 1068/1068 [00:26<00:00, 41.07it/s]
# eval: 100% 138/138 [00:03<00:00, 43.06it/s]
# save the model to sst-classifier.pt
# Epoch 1: train loss :: 1.536, train acc :: 0.404, dev acc :: 0.377
# train-2: 100% 1068/1068 [00:26<00:00, 39.81it/s]
# eval: 100% 1068/1068 [00:26<00:00, 41.05it/s]
# eval: 100% 138/138 [00:03<00:00, 43.42it/s]
# Epoch 2: train loss :: 1.505, train acc :: 0.328, dev acc :: 0.305
# train-3: 100% 1068/1068 [00:26<00:00, 40.62it/s]
# eval: 100% 1068/1068 [00:25<00:00, 41.39it/s]
# eval: 100% 138/138 [00:03<00:00, 41.70it/s]
# ...

# %%
# !pip install pytorch-lightning
# Out:
# ...
#   Using cached pytorch_lightning-2.2.4-py3-none-any.whl (802 kB)
# ...
#   Using cached torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
# ...
#   Using cached lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# !python multitask_classifier.py --fine-tune-mode last-linear-layer --lr 1e-3 --use_gpu
# Out:
# Loaded 8544 train examples from data/ids-sst-train.csv
# Loaded 283003 train examples from data/quora-train.csv
# Loaded 6040 train examples from data/sts-train.csv
# Loaded 1101 train examples from data/ids-sst-dev.csv
# Loaded 40429 train examples from data/quora-dev.csv
# Loaded 863 train examples from data/sts-dev.csv
# train-0: 100% 755/755 [01:17<00:00,  9.77it/s]
# eval: 100% 1068/1068 [00:24<00:00, 43.36it/s]
# eval: 100% 35376/35376 [20:48<00:00, 28.35it/s]
# eval: 100% 755/755 [00:25<00:00, 29.15it/s]
# Sentiment classification accuracy: 0.349
# Paraphrase detection accuracy: 0.632
# Semantic Textual Similarity correlation: -0.046
# eval: 100% 138/138 [00:03<00:00, 42.28it/s]
# eval: 100% 5054/5054 [02:58<00:00, 28.29it/s]
# eval: 100% 108/108 [00:03<00:00, 28.24it/s]
# Sentiment classification accuracy: 0.338
# Paraphrase detection accuracy: 0.633
# Semantic Textual Similarity correlation: -0.004
# save the model to last-linear-layer-10-0.001-multitask.pt
# ...
